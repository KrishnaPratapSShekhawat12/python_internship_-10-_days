# %% [markdown]
# <a href="https://colab.research.google.com/github/KrishnaPratapSShekhawat12/python_internship_-10-_days/blob/main/Day_3_Python_Internship.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello")
# Out:
# Hello

# %% [markdown]
# ---
# # List
# ---

# %%
myList=["apple","banana","orange"]
myList
# Out:
# ['apple', 'banana', 'orange']

# %%
type(myList)
# Out:
# list

# %%
myList[0]
# Out:
# 'apple'

# %%
myList[1:2]
# Out:
# ['banana']

# %%
myList[1:]
# Out:
# ['banana', 'orange']

# %%
myList.append('blue')

# %%
myList.append('cherry')
myList
# Out:
# ['apple', 'banana', 'orange', 'blue', 'cherry']

# %%
myList.count('apple')
# Out:
# 1

# %%
myList.append('apple')

# %%
myList
# Out:
# ['apple', 'banana', 'orange', 'blue', 'cherry', 'apple']

# %%
myList.count('apple')
# Out:
# 2

# %%
myList.sort()#O(nlogn)

# %%
myList
# Out:
# ['apple', 'apple', 'banana', 'blue', 'cherry', 'orange']

# %%
myList.pop(1)
# Out:
# 'apple'

# %%
myList
# Out:
# ['apple', 'banana', 'blue', 'cherry', 'orange']

# %%
myList.remove("banana")

# %%
myList
# Out:
# ['apple', 'blue', 'cherry', 'orange']

# %%
myList.clear()

# %%
myList
# Out:
# []

# %%
mylist=[x for x in ["apple", "banana","cherry"]]

# %%
mylist
# Out:
# ['apple', 'banana', 'cherry']

# %%
myList=[x for x in ["apple", "banana","cherry"]]

# %%
myList
# Out:
# ['apple', 'banana', 'cherry']

# %%
myList.reverse()

# %%
myList
# Out:
# ['cherry', 'banana', 'apple']

# %% [markdown]
# ---
# # Tuple
# ---

# %%
myTuple=("1","2","3","1")

# %%
type(myTuple)
# Out:
# tuple

# %%
myTuple.index("1")
# Out:
# 0

# %%
myTuple
# Out:
# ('1', '2', '3', '1')

# %%
myTuple.count("1")
# Out:
# 2

# %% [markdown]
# ---
# # Set
# ---

# %%
setmy={1,2,3,4,5,1}

# %%
type(setmy)
# Out:
# set

# %%
setmy
# Out:
# {1, 2, 3, 4, 5}

# %%
set1={1,3}
set2={1,4}

# %%
set3=set1.union(set2)

# %%
set3
# Out:
# {1, 3, 4}

# %%
set1 | set2
# Out:
# {1, 3, 4}

# %%
set1 & set2
# Out:
# {1}

# %%
set1.clear()

# %%
set1
# Out:
# set()

# %%
set1.update({1,2,3})

# %%
set1
# Out:
# {1, 2, 3}

# %% [markdown]
# ---
# # Dictionary
# ---

# %%
student={"name":"Vinamra","age":21}

# %%
type(student)
# Out:
# dict

# %%
student.keys()
# Out:
# dict_keys(['name', 'age'])

# %%
student.items()
# Out:
# dict_items([('name', 'Vinamra'), ('age', 21)])

# %%
student.pop("name")
# Out:
# 'Vinamra'

# %%
student
# Out:
# {'age': 21}

# %%
student.values()
# Out:
# dict_values([21])

# %%
text="Hello VGU "

# %%
text[0:5]
# Out:
# 'Hello'

# %%
text.find("VGU")
# Out:
# 6

# %%
text=text.replace("VGU","VGU Guys")

# %%
text
# Out:
# 'Hello VGU Guys '

# %%
text.split(" ")
# Out:
# ['Hello', 'VGU', 'Guys', '']

# %%
text
# Out:
# 'Hello VGU Guys '

# %%
text.split()
# Out:
# ['Hello', 'VGU', 'Guys']

# %%
text2=['Hello', 'VGU']
text3=" - ".join(text2)

# %%
text3
# Out:
# 'Hello - VGU'

# %% [markdown]
# ---
# # File Handling
# ---

# %%
file=open("myfile.txt","w")

# %%
file.write("Hello I'm written from python code")
# Out:
# 34

# %%
file.close()

# %%
file=open("myfile.txt","r")
print(file.read())
file.close()
# Out:
# Hello I'm written from python code

# %%
with open("myfile.txt","w") as f:
    f.write("Hello")

# %%
with open("myfile.txt","a") as f:
    f.write("hehe")
