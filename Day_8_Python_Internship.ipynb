# %% [markdown]
# <a href="https://colab.research.google.com/github/KrishnaPratapSShekhawat12/python_internship_-10-_days/blob/main/Day_8_Python_Internship.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import smtplib

# %%
import ssl

# %%
from email.message import EmailMessage

# %%
email="kpkpratapsinghshekhawat@gmail.com"
app_password="Your app Password here "
receiver="aaryanparmar69@gmail.coaaryanparmar69@gmail.com"

# %%
msg=EmailMessage()

# %%
msg["From"]=email
msg["To"]=receiver
msg["Subject"]="Hello from Python ..."

# %%
msg.set_content("This email was shared by Python ")

# %%
context=ssl.create_default_context()

# %%
import smtplib, ssl
from email.message import EmailMessage

email = "your.email@gmail.com"
# create an app password in your Google account (not your normal password)
app_password = "xxxxxxxxxxxxxxxx"

msg = EmailMessage()
msg["Subject"] = "Test email from Python"
msg["From"] = email
msg["To"] = "recipient@example.com"
msg.set_content("Hello — this is a test sent over SMTP_SSL on port 465.")

context = ssl.create_default_context()

try:
    with smtplib.SMTP_SSL("smtp.gmail.com", 465, context=context) as server:
            server.login(email, app_password)
                    server.send_message(msg)
                        print("Mail sent")
                        except smtplib.SMTPAuthenticationError as e:
                            print("Auth error:", e)
                            except Exception as e:
                                print("Failed to send mail:", e)
# Out:
#   File "/tmp/ipython-input-722662101.py", line 19
#     server.send_message(msg)
#     ^
# IndentationError: unexpected indent
