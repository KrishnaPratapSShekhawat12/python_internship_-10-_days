# %% [markdown]
# <a href="https://colab.research.google.com/github/KrishnaPratapSShekhawat12/python_internship_-10-_days/blob/main/Day_4_Python_Internship.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def print_name(n):
    print(f'Hi {n}')

# %%
print_name(" Krishna ")
# Out:
# Hi  Krishna

# %%
def multi_args(*args):
    print(args)

# %%
multi_args("hhbdhd","sdbhd")
# Out:
# ('hhbdhd', 'sdbhd')

# %%
def student(**info):
    for key , value in info.items():
        print(key, ":", value)

# %%
tom_details=student(name="Tom",contact=123)
# Out:
# name : Tom
# contact : 123

# %%
def myfunc(a,b):
    return a+b, a-b

# %%
myfunc(3,5)
# Out:
# (8, -2)

# %%
double= lambda x: x*2

# %%
double(5)
# Out:
# 10

# %%
triple=lambda x:x*3

# %%
triple(10)
# Out:
# 30

# %%
# import function

# %%
print_name(" Krishna ")
# Out:
# Hi  Krishna

# %%
import math

# %%
math.sqrt(16)
# Out:
# 4.0

# %%
from math import sqrt

# %%
# create file in Colab
# %%bash
cat > function.py <<'PY'
def greet(name="Student"):
    return f"Hello, {name}!"
    PYfrom function import greet
    print(greet("Krishna"))
# Out:
# bash: line 5: warning: here-document at line 1 delimited by end-of-file (wanted `PY')

# %%
import random as r

# %%
r.randint(1,20)
# Out:
# 5

# %%
import datetime as d

# %%
print(d.time())
# Out:
# 00:00:00

# %%
try:
    print("Hello\n")
except SyntaxError:
    print("Use the correct syntax")
# Out:
# Hello
